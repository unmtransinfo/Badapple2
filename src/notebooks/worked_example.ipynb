# %% [markdown]
# # Worked Examples
# This notebook provides an examples of input compounds and the derived scaffold found to be highest-scoring in the badappl2 database (DB), alongside explanations of these scores via details on the scaffold's associated compounds, substances and assays from PubChem.

# %% [markdown]
# ## Background

# %% [markdown]
# ### PubChem
# PubChem (https://pubchem.ncbi.nlm.nih.gov/) is a public chemistry database maintained by the NIH. PubChem includes records for over 100 million compounds and data from over 1 million bioassays.
#
#
# For more information about PubChem see: https://pubchem.ncbi.nlm.nih.gov/docs/about

# %% [markdown]
# #### BioAssays
# The PubChem bioassay database contains over 200 million bioassay outcomes across over 1 million bioassays. Assay data is deposited to PubChem from sources (including universities, government labs, pharmaceutical companies, etc) around the world. Each assay record is uniquely identified via its AssayID (AID).
#
# For more info see: https://pubchem.ncbi.nlm.nih.gov/docs/bioassays

# %% [markdown]
# #### Substances
# "Substance" refers to depositor-provided data for a chemical entity. Note that not all substances are necessarily compounds, e.g. [Green Tea Leaf](https://pubchem.ncbi.nlm.nih.gov/substance/482031919). Substances are uniquely identified via their SubstanceID (SID).
#
# For more info see: https://pubchem.ncbi.nlm.nih.gov/docs/substances

# %% [markdown]
# #### Compounds
# A compound is a unique, discrete chemical structure obtained from one or more substances via a [standardization process](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4702940/#SEC3-2). One compound can be associated with 1 or more substances. Compounds are uniquely identified via their CompoundID (CID).
#
# For more info see: https://pubchem.ncbi.nlm.nih.gov/docs/compounds

# %% [markdown]
# ### Badapple (bioassay-data associative promiscuity pattern learning engine)
# Badapple is a statistical method for identifying likely promiscuous compounds via their associated scaffolds, using data gathered from PubChem, and in particular data from the [Molecular Libraries Small Molecules Program](https://pubchem.ncbi.nlm.nih.gov/source/MLSMR).
#
# Original Badapple paper: https://jcheminf.biomedcentral.com/articles/10.1186/s13321-016-0137-3

# %% [markdown]
# #### Badapple Score Calculation
# Based on the data gathered from PubChem, badapple calculates a "promiscuity score" (pscore) for a given scaffold using the following formula:
#
# $$
# \begin{aligned} pscore & = \frac{{s_{A} }}{{s_{T} + med(s_{T} )}} \times \frac{{a_{A} }}{{a_{T} + med(a_{T} )}} \quad \times \frac{{w_{A} }}{{w_{T} + med(w_{T} )}} \times 1e5 \\ \end{aligned}
# $$
#
# Where:
# | Symbol       | Description                      | Value |
# |--------------|----------------------------------|-------|
# | $s_{T}$      | tested substances                |       |
# | $s_{A}$      | active substances                |       |
# | $a_{T}$      | assays with tested compounds     |       |
# | $a_{A}$      | assays with active compounds     |       |
# | $w_{T}$      | tested samples                   |       |
# | $w_{A}$      | active samples                   |       |
# | $med$        | median                           |       |
# | $med(s_{T})$ | median of tested substances       | 2     |
# | $med(a_{T})$ | median of assays with tested compounds | 634   |
# | $med(w_{T})$ | median of tested samples          | 773   |
#
# Note that "sample" here refers to an instance of a substance in an assay, i.e. a single bioactivity outcome.
#
# In the case of badapple_classic, the set of compounds used included all MLSMR compounds. In badapple2, we label scaffold stats/scores using data from all compounds tested in at least 50 unique assays (to ensure data is coming from compounds which have been sufficiently tested, otherwise $s_A / s_T$ would significantly decrease).

# %% [markdown]
# #### Badapple score meaning
# In Badapple, a higher score indicates a higher chance that a scaffold is promiscuous. The table below provides an overview of score ranges and their corresponding advisory:
#
# | **pScore range** | **Advisory** |
# |------------------|--------------|
# | ~                | Unknown; no data |
# | 0–99             | Low pScore; no indication |
# | 100–299          | Moderate pScore; weak indication of promiscuity |
# | 300+             | High pScore; strong indication of promiscuity |
#
# Note that the pscore for a given scaffold will only be high if there is a large amount of evidence, given the medians in the denominator. One can see from the figure [here](https://github.com/unmtransinfo/Badapple2/blob/main/figures/badapple_classic_formula.png) that scores cannot pass into the "Moderate" and "High" range unless the number of assays tested surpasses a certain threshold.

# %% [markdown]
# #### Example score calculations
# If a scaffold is only present in one substance that is active in one assay then the pscore will not be high:
# $$
# \begin{aligned} \frac{{1 }}{{1 + med(s_{T} )}} \times \frac{1}{{1 + med(a_{T} )}} \quad \times \frac{{1 }}{{1 + med(w_{T} )}} \times 1e5  = 0.07 \\ \end{aligned}
# $$
#
# On the other hand, if a scaffold is present in 70 tested substances across 600 different assays in $42000$ samples, and 10/70 of those substances are active in 300/600 of the assays in a total of $18000$ samples* then the score will be high:
# $$
# \begin{aligned} \frac{{10}}{{70 + med(s_{T} )}} \times \frac{300}{{600 + med(a_{T} )}} \quad \times \frac{{18000 }}{{42000 + med(w_{T} )}} \times 1e5 = 1420.94 \\ \end{aligned}
# $$
#
# In practice scores around rounded to the nearest whole number.
#
# *Note that the number of samples per substance can vary. There are also some (rare) cases where a substance is tested multiple times in the same assay. For example, see [SID 4258900](https://pubchem.ncbi.nlm.nih.gov/substance/4258900) (substance) in [AID 651965](https://pubchem.ncbi.nlm.nih.gov/bioassay/651965) (assay).

# %% [markdown]
# ## Code Setup
# Imports, function definitions. This code uses the [Badapple2-API](https://github.com/unmtransinfo/Badapple2-API) to fetch information from the DB.

# %%
BASE_URL = "http://localhost:8000/api/v1"
DATABASE = "badapple2" # other valid option is badapple_classic
MIN_NASS_TESTED = 50 # in badapple2 only data from compounds tested in >= 50 assays is used to label scaffold stats / compute pScores

# %%
# imports
import requests
from rdkit import Chem
import pandas as pd
from IPython.display import display, HTML

# %%
def get_request_data(request_url: str):
    result = requests.get(request_url)
    res = {}
    if result.status_code == 200:
        res = result.json()
    else:
        print(result)
    return res

# %%
def get_mol_scaffolds(mol_smiles: str):
    request_url = f"{BASE_URL}/compound_search/get_associated_scaffolds?SMILES={mol_smiles}&database={DATABASE}"
    return get_request_data(request_url)

# %%
def get_associated_pubchem_compounds(scafid: int):
    request_url = f"{BASE_URL}/scaffold_search/get_associated_compounds?scafid={scafid}&database={DATABASE}"
    return get_request_data(request_url)

# %%
def get_associated_pubchem_substances(cid_list: list[int]):
    formatted_inp = ','.join(str(cid) for cid in cid_list)
    request_url = f"{BASE_URL}/compound_search/get_associated_substance_ids?CIDs={formatted_inp}&database={DATABASE}"
    return get_request_data(request_url)

# %%
def get_assay_outcomes(sid: int):
    request_url = f"{BASE_URL}/substance_search/get_assay_outcomes?SID={sid}&database={DATABASE}"
    return get_request_data(request_url)

# %%
def create_clickable_urls(id_list: int, base_url: str):
    if isinstance(id_list, int):
        id_list = [id_list]
    return [f'<a href="{base_url}{ID}" target="_blank">{ID}</a>'  for ID in id_list]

# %%
# create df that has clickable links to PubChem pages for Compounds, Substances, and Assays
def create_clickable_df(df_og: pd.DataFrame, id_cols: list[str], base_urls: list[str]):
    df = df_og.copy()
    for col, base_url in zip(id_cols, base_urls):
        df[col] = df[col].apply(lambda ids: create_clickable_urls(ids, base_url))
        df[col] = df[col].apply(lambda urls: ', '.join(urls))
    return display(HTML(df.to_html(escape=False)))

# %%
def get_scaf_legend(scaf_info: dict):
    s = f"SMILES: {scaf_info['scafsmi']}\n"
    s+= f"in_db: {scaf_info["in_db"]}"
    if scaf_info["in_db"]:
        s += f" | pscore {scaf_info["pscore"]} | ID: {scaf_info["id"]}"
    return s

# %%
def get_mol_scaf_grid(mol_smiles: str, scaf_info_list: list[dict]):
    # process mol
    mol_legend = f"Molecule SMILES = {mol_smiles}"
    mol = Chem.MolFromSmiles(mol_smiles)

    # process scafs
    scaf_mols = [Chem.MolFromSmiles(d['scafsmi']) for d in scaf_info_list]
    scaf_legends = [get_scaf_legend(d) for d in scaf_info_list]

    # combine and draw
    mol_matrix = [[mol]] + [[scaf] for scaf in scaf_mols]
    legend_matrix = [[mol_legend]] + [[legend] for legend in scaf_legends]
    return Chem.Draw.MolsMatrixToGridImage(molsMatrix=mol_matrix, legendsMatrix=legend_matrix, useSVG=True, subImgSize=(600, 300))

# %%
def get_mols_grid(mol_smiles_list: list[str], legends: list, mols_per_row: int):
    mols = [Chem.MolFromSmiles(smi) for smi in mol_smiles_list]
    img = Chem.Draw.MolsToGridImage(mols=mols, legends=legends, molsPerRow=mols_per_row, useSVG=True, subImgSize=(300, 300))
    return img

# %%
def compute_pscore(
    sTested: int,
    sActive: int,
    aTested: int,
    aActive: int,
    wTested: int,
    wActive: int,
    median_sTested: float = 2.0,
    median_aTested: float = 634,
    median_wTested: float = 773,
) -> float:
    if sTested == 0 or aTested == 0 or wTested == 0:
        return None  # None means no evidence

    pScore = (
        1.0
        * sActive
        / (sTested + median_sTested)
        * aActive
        / (aTested + median_aTested)
        * wActive
        / (wTested + median_wTested)
        * 1e5
    )
    pScore = round(pScore, 0)  
    return pScore

# %% [markdown]
# ## Set input mol

# %%
# of a set of 20k+ compounds, this one had the highest-scoring scaffold
mol_smiles = "CN(C)c1cc(NCCN2CCC3(CC2)OCCO3)c2c3c(onc13)-c1ccccc1C2=O"

# %% [markdown]
# ## Visualize Molecule + all of its scaffolds

# %%
mol_scaffolds = get_mol_scaffolds(mol_smiles)
# API returns dict mapping input SMILES to their list of scaffolds
mol_scaffolds = mol_scaffolds[mol_smiles]

# %%
get_mol_scaf_grid(mol_smiles, mol_scaffolds)

# %% [markdown]
# ## Analysis of highest-scoring scaffold
# The sections below dives into why the scaffold with SMILES `O=C1c2ccccc2-c2onc3cccc1c23` has been assigned the score that it has. In particular, we look at the statistics as well as all the associated PubChem compounds, substances, and assays that were found to be linked to this scaffold in the Badapple DB.
#
# In addition, there has been literature published about this particular scaffold, as identified in the original Badapple paper: "Scaffold a 6H-anthra[1,9-cd]isoxazol-6-one is known to react with DMSO acting as a nucleophile and undergoes N–O cleavage of the isoxazole ring to form the ring opened anthraquinone, a species known to form covalent adducts" (https://jcheminf.biomedcentral.com/articles/10.1186/s13321-016-0137-3/tables/7)

# %%
highest_scoring_scaffold_smiles = "O=C1c2ccccc2-c2onc3cccc1c23" # see above
get_mols_grid([highest_scoring_scaffold_smiles], ["Scaffold"], 1)

# %%
scafid = 814 # see above

# %%
COMPOUND_BASE_URL = "https://pubchem.ncbi.nlm.nih.gov/compound/"
SUBSTANCE_BASE_URL = "https://pubchem.ncbi.nlm.nih.gov/substance/"
ASSAY_BASE_URL = "https://pubchem.ncbi.nlm.nih.gov/bioassay/"

# %% [markdown]
# ### Scaffold Details
# Badapple contains not only the scores of a given scaffold, but also other information. The column titles are mostly self-descriptive (see background on Badapple above), although we note that `in_drug` denotes if the scaffold is found in any drugs from [DrugCentral](https://drugcentral.org/), which includes approved drugs from the FDA, EMA, and PMDA.

# %%
mol_scaffolds_df = pd.DataFrame(mol_scaffolds)
scaf_row_idx = mol_scaffolds_df.index[mol_scaffolds_df['id']==scafid][0]
scaf_row = mol_scaffolds_df.iloc[scaf_row_idx]
scaf_row
# Out:
# id                                              814
# in_db                                          True
# in_drug                                       False
# kekule_scafsmi    O=C1C2=CC=CC=C2C2=C3C1=CC=CC3=NO2
# nass_active                                     366
# nass_tested                                     870
# ncpd_active                                      31
# ncpd_tested                                      31
# ncpd_total                                       31
# nsam_active                                    1229
# nsam_tested                                   12188
# nsub_active                                      34
# nsub_tested                                      48
# nsub_total                                       48
# prank                                            14
# pscore                                       1569.0
# scafsmi                 O=C1c2ccccc2-c2onc3cccc1c23
# scaftree                                        814
# Name: 1, dtype: object

# %% [markdown]
# We can also see that the pscore calculation matches what we'd calculate from the statistics

# %%
print("pscore from DB:", scaf_row["pscore"])
calculated_pscore = compute_pscore(scaf_row["nsub_tested"], scaf_row["nsub_active"],
                                    scaf_row["nass_tested"], scaf_row["nass_active"],
                                    scaf_row["nsam_tested"], scaf_row["nsam_active"])
print("pscore calculated from stats:", calculated_pscore)
# Out:
# pscore from DB: 1569.0
# pscore calculated from stats: 1569.0

# %% [markdown]
# ### Compounds
# Since this scaffold was found in the Badapple DB, we know it most be associated with 1 or more compounds from PubChem present in the DB. Here we view and get other information related to each of these associated compounds. By clicking on a given CID you can view additional information.

# %%
associated_compounds = get_associated_pubchem_compounds(scafid)
associated_compounds_df = pd.DataFrame(associated_compounds)
associated_compounds_df = associated_compounds_df.sort_values(by="cid").reset_index(drop=True)
associated_compounds_df = associated_compounds_df.rename(columns={"cid": "CID"})
associated_compounds_df = associated_compounds_df.drop(columns=["cansmi"]) # have isomeric SMILES
# reducing to compounds used to actually label stats - in badapple_classic this was done implicitly via MLSMR restriction
if DATABASE == "badapple2":
    associated_compounds_df = associated_compounds_df[associated_compounds_df["nass_tested"] >= MIN_NASS_TESTED]
associated_compounds_df
# Out:
#           CID                                             isosmi  nass_active  \
# 1      659226  CCOC(=O)C(C1=C2C3=C(C4=CC=CC=C4C2=O)ON=C3C(=C1...          121
# 2      659413  C1=CC=C2C(=C1)C3=C4C(=NO3)C=CC(=C4C2=O)NCC5=CC...          105
# 3      663844  C1=CC=C2C(=C1)C3=C4C(=NO3)C=CC(=C4C2=O)NCCCN5C...           99
# 4      672470             CCOC1=C2C3=C(C4=CC=CC=C4C2=O)ON=C3C=C1           47
# 12     774975              COC1=C2C3=C(C4=CC=CC=C4C2=O)ON=C3C=C1           79
# 17     776361             CCNC1=C2C3=C(C4=CC=CC=C4C2=O)ON=C3C=C1          104
# 20     776370       C1CCN(C1)C2=C3C4=C(C5=CC=CC=C5C3=O)ON=C4C=C2           64
# 21     776372  C1=CC=C(C=C1)OC2=C3C4=C(C5=CC=CC=C5C3=O)ON=C4C=C2           58
# 89    1916369  COC(CNC(=O)C1=CC=C2C3=C(C4=CC=CC=C4C2=O)ON=C13)OC           53
# 100   2246180  C1=CC=C(C=C1)OC2=CC(=C3C4=C(C5=CC=CC=C5C3=O)ON...           18
# 107   3239469  C1CN(CCC12OCCO2)C3=CC(=C4C5=C(C6=CC=CC=C6C4=O)...           54
# 108   3245701  CCOC(=O)N1CCN(CC1)C2=CC(=C3C4=C(C5=CC=CC=C5C3=...           68
# 167   3729555     COCCCNC(=O)C1=CC=C2C3=C(C4=CC=CC=C4C2=O)ON=C13           54
# 243   5052536  C1CN(CCN1C2=CC(=C3C4=C(C5=CC=CC=C5C3=O)ON=C24)...           53
# 256   5308727  CC(=O)OCCNC1=C2C3=C(C4=CC=CC=C4C2=O)ON=C3C(=C1...           29
# 269  15987713  C1CCC(CC1)N2CCN(CC2)C3=CC(=C4C5=C(C6=CC=CC=C6C...            9
# 296  16009232  CCCCNC1=C2C3=C(C4=CC=CC=C4C2=O)ON=C3C(=C1)N5CC...            5
# 297  16009234  C1CCC(CC1)NC2=C3C4=C(C5=CC=CC=C5C3=O)ON=C4C(=C...            2
# 298  16009236  CCN(CC)C1=CC(=C2C3=C(C4=CC=CC=C4C2=O)ON=C13)NC...            6
# 299  16009237  CC(C)CNC1=CC(=C2C3=C(C4=CC=CC=C4C2=O)ON=C13)NC...            3
# 300  16009248  CCCCNC1=CC(=C2C3=C(C4=CC=CC=C4C2=O)ON=C13)NC5C...            4
# 301  16009250  CC(C)NC1=C2C3=C(C4=CC=CC=C4C2=O)ON=C3C(=C1)N5C...            2
# 302  16009252  C1CCC(CC1)NC2=C3C4=C(C5=CC=CC=C5C3=O)ON=C4C(=C...           10
# 303  16009254  C1CCC(CC1)N2CCN(CC2)C3=CC(=C4C5=C(C6=CC=CC=C6C...            6
# 304  16009256  CCNC1=C2C3=C(C4=CC=CC=C4C2=O)ON=C3C(=C1)N5CCN(...            3
# 305  16009258  COCCNC1=C2C3=C(C4=CC=CC=C4C2=O)ON=C3C(=C1)N5CC...            5
# 306  16009259  CN(C)CCCNC1=C2C3=C(C4=CC=CC=C4C2=O)ON=C3C(=C1)...           11
# 374  20868233  CCN1CCN(CC1)C2=CC(=C3C4=C(C5=CC=CC=C5C3=O)ON=C...           31
# 375  20868238  CN1CCN(CC1)C2=CC(=C3C4=C(C5=CC=CC=C5C3=O)ON=C2...           26
# 376  20868240  C1CN(CCN1CCO)C2=CC(=C3C4=C(C5=CC=CC=C5C3=O)ON=...           37
# 389  24789635  C1CN(CCN1C2=CC(=C3C4=C(C5=CC=CC=C5C3=O)ON=C24)...           63
#
#      nass_tested  nsam_active  nsam_tested  nsub_active  nsub_tested  \
# 1            760          121          760            2            2
# 2            689          105          690            1            2
# 3            611           99          611            1            1
# 4            760           47          764            1            4
# 12           505           79          508            2            3
# 17           676          104          677            1            2
# 20           545           64          545            1            1
# 21           692           58          692            1            2
# 89           575           53          575            1            1
# 100          294           18          294            1            2
# 107          473           54          473            1            1
# 108          694           68          694            1            1
# 167          510           54          510            1            1
# 243          510           53          510            1            2
# 256          650           29          652            2            3
# 269          113            9          113            1            2
# 296          111            5          111            1            1
# 297          111            2          111            1            1
# 298          113            6          113            1            1
# 299          113            3          113            1            1
# 300          113            4          113            1            1
# 301          111            2          111            1            1
# 302          114           10          114            1            2
# 303          110            6          110            1            1
# 304          110            3          110            1            1
# 305          110            5          110            1            1
# 306          111           11          111            1            1
# 374          441           31          441            1            2
# 375          441           26          441            1            1
# 376          503           37          503            1            2
# 389          508           63          508            1            1
#
#      nsub_total
# 1             2
# 2             2
# 3             1
# 4             4
# 12            3
# 17            2
# 20            1
# 21            2
# 89            1
# 100           2
# 107           1
# 108           1
# 167           1
# 243           2
# 256           3
# 269           2
# 296           1
# 297           1
# 298           1
# 299           1
# 300           1
# 301           1
# 302           2
# 303           1
# 304           1
# 305           1
# 306           1
# 374           2
# 375           1
# 376           2
# 389           1

# %%
associated_compound_smiles = associated_compounds_df["isosmi"].tolist()
legends = [f"CID: {cid}" for cid in associated_compounds_df["CID"]]
get_mols_grid(associated_compound_smiles, legends, 3)

# %%
create_clickable_df(associated_compounds_df, ["CID"], [COMPOUND_BASE_URL])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CID</th>
#       <th>isosmi</th>
#       <th>nass_active</th>
#       <th>nass_tested</th>
#       <th>nsam_active</th>
#       <th>nsam_tested</th>
#       <th>nsub_active</th>
#       <th>nsub_tested</th>
#       <th>nsub_total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/659226" target="_blank">659226</a></td>
#       <td>CCOC(=O)C(C1=C2C3=C(C4=CC=CC=C4C2=O)ON=C3C(=C1)Br)C(=O)OCC</td>
#       <td>121</td>
#       <td>760</td>
#       <td>121</td>
#       <td>760</td>
#       <td>2</td>
#       <td>2</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/659413" target="_blank">659413</a></td>
#       <td>C1=CC=C2C(=C1)C3=C4C(=NO3)C=CC(=C4C2=O)NCC5=CC=CO5</td>
#       <td>105</td>
#       <td>689</td>
#       <td>105</td>
#       <td>690</td>
#       <td>1</td>
#       <td>2</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/663844" target="_blank">663844</a></td>
#       <td>C1=CC=C2C(=C1)C3=C4C(=NO3)C=CC(=C4C2=O)NCCCN5C=CN=C5</td>
#       <td>99</td>
#       <td>611</td>
#       <td>99</td>
#       <td>611</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/672470" target="_blank">672470</a></td>
#       <td>CCOC1=C2C3=C(C4=CC=CC=C4C2=O)ON=C3C=C1</td>
#       <td>47</td>
#       <td>760</td>
#       <td>47</td>
#       <td>764</td>
#       <td>1</td>
#       <td>4</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/774975" target="_blank">774975</a></td>
#       <td>COC1=C2C3=C(C4=CC=CC=C4C2=O)ON=C3C=C1</td>
#       <td>79</td>
#       <td>505</td>
#       <td>79</td>
#       <td>508</td>
#       <td>2</td>
#       <td>3</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/776361" target="_blank">776361</a></td>
#       <td>CCNC1=C2C3=C(C4=CC=CC=C4C2=O)ON=C3C=C1</td>
#       <td>104</td>
#       <td>676</td>
#       <td>104</td>
#       <td>677</td>
#       <td>1</td>
#       <td>2</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/776370" target="_blank">776370</a></td>
#       <td>C1CCN(C1)C2=C3C4=C(C5=CC=CC=C5C3=O)ON=C4C=C2</td>
#       <td>64</td>
#       <td>545</td>
#       <td>64</td>
#       <td>545</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/776372" target="_blank">776372</a></td>
#       <td>C1=CC=C(C=C1)OC2=C3C4=C(C5=CC=CC=C5C3=O)ON=C4C=C2</td>
#       <td>58</td>
#       <td>692</td>
#       <td>58</td>
#       <td>692</td>
#       <td>1</td>
#       <td>2</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>89</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/1916369" target="_blank">1916369</a></td>
#       <td>COC(CNC(=O)C1=CC=C2C3=C(C4=CC=CC=C4C2=O)ON=C13)OC</td>
#       <td>53</td>
#       <td>575</td>
#       <td>53</td>
#       <td>575</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>100</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/2246180" target="_blank">2246180</a></td>
#       <td>C1=CC=C(C=C1)OC2=CC(=C3C4=C(C5=CC=CC=C5C3=O)ON=C24)O</td>
#       <td>18</td>
#       <td>294</td>
#       <td>18</td>
#       <td>294</td>
#       <td>1</td>
#       <td>2</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>107</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/3239469" target="_blank">3239469</a></td>
#       <td>C1CN(CCC12OCCO2)C3=CC(=C4C5=C(C6=CC=CC=C6C4=O)ON=C35)NCCCC(=O)O</td>
#       <td>54</td>
#       <td>473</td>
#       <td>54</td>
#       <td>473</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>108</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/3245701" target="_blank">3245701</a></td>
#       <td>CCOC(=O)N1CCN(CC1)C2=CC(=C3C4=C(C5=CC=CC=C5C3=O)ON=C24)NCCC(=O)O</td>
#       <td>68</td>
#       <td>694</td>
#       <td>68</td>
#       <td>694</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>167</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/3729555" target="_blank">3729555</a></td>
#       <td>COCCCNC(=O)C1=CC=C2C3=C(C4=CC=CC=C4C2=O)ON=C13</td>
#       <td>54</td>
#       <td>510</td>
#       <td>54</td>
#       <td>510</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>243</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/5052536" target="_blank">5052536</a></td>
#       <td>C1CN(CCN1C2=CC(=C3C4=C(C5=CC=CC=C5C3=O)ON=C24)NCCCC(=O)O)C(=O)C6=CC=CO6</td>
#       <td>53</td>
#       <td>510</td>
#       <td>53</td>
#       <td>510</td>
#       <td>1</td>
#       <td>2</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>256</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/5308727" target="_blank">5308727</a></td>
#       <td>CC(=O)OCCNC1=C2C3=C(C4=CC=CC=C4C2=O)ON=C3C(=C1)N5CCN(CC5)C</td>
#       <td>29</td>
#       <td>650</td>
#       <td>29</td>
#       <td>652</td>
#       <td>2</td>
#       <td>3</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>269</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/15987713" target="_blank">15987713</a></td>
#       <td>C1CCC(CC1)N2CCN(CC2)C3=CC(=C4C5=C(C6=CC=CC=C6C4=O)ON=C35)NCCCC(=O)O</td>
#       <td>9</td>
#       <td>113</td>
#       <td>9</td>
#       <td>113</td>
#       <td>1</td>
#       <td>2</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>296</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/16009232" target="_blank">16009232</a></td>
#       <td>CCCCNC1=C2C3=C(C4=CC=CC=C4C2=O)ON=C3C(=C1)N5CCN(CC5)C6CCCCC6</td>
#       <td>5</td>
#       <td>111</td>
#       <td>5</td>
#       <td>111</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>297</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/16009234" target="_blank">16009234</a></td>
#       <td>C1CCC(CC1)NC2=C3C4=C(C5=CC=CC=C5C3=O)ON=C4C(=C2)Br</td>
#       <td>2</td>
#       <td>111</td>
#       <td>2</td>
#       <td>111</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>298</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/16009236" target="_blank">16009236</a></td>
#       <td>CCN(CC)C1=CC(=C2C3=C(C4=CC=CC=C4C2=O)ON=C13)NC5CCCCC5</td>
#       <td>6</td>
#       <td>113</td>
#       <td>6</td>
#       <td>113</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>299</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/16009237" target="_blank">16009237</a></td>
#       <td>CC(C)CNC1=CC(=C2C3=C(C4=CC=CC=C4C2=O)ON=C13)NC5CCCCC5</td>
#       <td>3</td>
#       <td>113</td>
#       <td>3</td>
#       <td>113</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>300</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/16009248" target="_blank">16009248</a></td>
#       <td>CCCCNC1=CC(=C2C3=C(C4=CC=CC=C4C2=O)ON=C13)NC5CCCCC5</td>
#       <td>4</td>
#       <td>113</td>
#       <td>4</td>
#       <td>113</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>301</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/16009250" target="_blank">16009250</a></td>
#       <td>CC(C)NC1=C2C3=C(C4=CC=CC=C4C2=O)ON=C3C(=C1)N5CCN(CC5)C6CCCCC6</td>
#       <td>2</td>
#       <td>111</td>
#       <td>2</td>
#       <td>111</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>302</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/16009252" target="_blank">16009252</a></td>
#       <td>C1CCC(CC1)NC2=C3C4=C(C5=CC=CC=C5C3=O)ON=C4C(=C2)NCCO</td>
#       <td>10</td>
#       <td>114</td>
#       <td>10</td>
#       <td>114</td>
#       <td>1</td>

# %% [markdown]
# ### Substances
# In PubChem, a given compound can be associated with 1+ substances. The code below pulls the SIDs associated with each of the compounds above, and provides clickable links for each SID with additional information.

# %%
cid_list = associated_compounds_df["CID"].tolist()

# %%
associated_substances = get_associated_pubchem_substances(cid_list)
associated_substances_df = pd.DataFrame(associated_substances)

# %%
create_clickable_df(associated_substances_df, ["CID", "SIDs"], [COMPOUND_BASE_URL, SUBSTANCE_BASE_URL])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>CID</th>
#       <th>SIDs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/659226" target="_blank">659226</a></td>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/substance/857882" target="_blank">857882</a>, <a href="https://pubchem.ncbi.nlm.nih.gov/substance/24841017" target="_blank">24841017</a></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/659413" target="_blank">659413</a></td>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/substance/858057" target="_blank">858057</a>, <a href="https://pubchem.ncbi.nlm.nih.gov/substance/50103419" target="_blank">50103419</a></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/663844" target="_blank">663844</a></td>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/substance/862610" target="_blank">862610</a></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/672470" target="_blank">672470</a></td>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/substance/7974300" target="_blank">7974300</a>, <a href="https://pubchem.ncbi.nlm.nih.gov/substance/17443393" target="_blank">17443393</a>, <a href="https://pubchem.ncbi.nlm.nih.gov/substance/24343610" target="_blank">24343610</a>, <a href="https://pubchem.ncbi.nlm.nih.gov/substance/333269648" target="_blank">333269648</a></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/774975" target="_blank">774975</a></td>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/substance/7973721" target="_blank">7973721</a>, <a href="https://pubchem.ncbi.nlm.nih.gov/substance/17443744" target="_blank">17443744</a>, <a href="https://pubchem.ncbi.nlm.nih.gov/substance/333264490" target="_blank">333264490</a></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/776361" target="_blank">776361</a></td>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/substance/14724300" target="_blank">14724300</a>, <a href="https://pubchem.ncbi.nlm.nih.gov/substance/17444225" target="_blank">17444225</a></td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/776370" target="_blank">776370</a></td>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/substance/24809038" target="_blank">24809038</a></td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/776372" target="_blank">776372</a></td>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/substance/14724311" target="_blank">14724311</a>, <a href="https://pubchem.ncbi.nlm.nih.gov/substance/333264611" target="_blank">333264611</a></td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/1916369" target="_blank">1916369</a></td>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/substance/26659756" target="_blank">26659756</a></td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/2246180" target="_blank">2246180</a></td>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/substance/14720421" target="_blank">14720421</a>, <a href="https://pubchem.ncbi.nlm.nih.gov/substance/333264851" target="_blank">333264851</a></td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/3239469" target="_blank">3239469</a></td>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/substance/4244935" target="_blank">4244935</a></td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/3245701" target="_blank">3245701</a></td>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/substance/4252106" target="_blank">4252106</a></td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/3729555" target="_blank">3729555</a></td>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/substance/26659725" target="_blank">26659725</a></td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/5052536" target="_blank">5052536</a></td>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/substance/24316919" target="_blank">24316919</a>, <a href="https://pubchem.ncbi.nlm.nih.gov/substance/49734932" target="_blank">49734932</a></td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/5308727" target="_blank">5308727</a></td>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/substance/7967276" target="_blank">7967276</a>, <a href="https://pubchem.ncbi.nlm.nih.gov/substance/87343549" target="_blank">87343549</a>, <a href="https://pubchem.ncbi.nlm.nih.gov/substance/332972488" target="_blank">332972488</a></td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/15987713" target="_blank">15987713</a></td>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/substance/24267373" target="_blank">24267373</a>, <a href="https://pubchem.ncbi.nlm.nih.gov/substance/24355194" target="_blank">24355194</a></td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/16009232" target="_blank">16009232</a></td>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/substance/24385612" target="_blank">24385612</a></td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/16009234" target="_blank">16009234</a></td>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/substance/24385614" target="_blank">24385614</a></td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/16009236" target="_blank">16009236</a></td>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/substance/24385616" target="_blank">24385616</a></td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/16009237" target="_blank">16009237</a></td>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/substance/24385618" target="_blank">24385618</a></td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/16009248" target="_blank">16009248</a></td>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/substance/24385636" target="_blank">24385636</a></td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/16009250" target="_blank">16009250</a></td>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/substance/24385638" target="_blank">24385638</a></td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/16009252" target="_blank">16009252</a></td>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/substance/24385640" target="_blank">24385640</a>, <a href="https://pubchem.ncbi.nlm.nih.gov/substance/332972857" target="_blank">332972857</a></td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/16009254" target="_blank">16009254</a></td>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/substance/24385642" target="_blank">24385642</a></td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/16009256" target="_blank">16009256</a></td>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/substance/24385644" target="_blank">24385644</a></td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/compound/16009258" target="_blank">16009258</a></td>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/substance/24385646" target="_blank">24385646</a></td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td><a href="https://pubchem.ncbi.nl

# %% [markdown]
# ### Assays
# Given that many of the substances above are associated with >100 different assays in the DB, I'm choosing to show a sample of 20 assays for a couple of selected substances.

# %% [markdown]
# #### Helper functions

# %%
# activity outcomes are coded according to the following:
###   1 = inactive
###   2 = active
###   3 = inconclusive
###   4 = unspecified
###   5 = probe
###   multiple & differing 1, 2 or 3 = discrepant
MAPPING = {1: "Inactive", 2: "Active", 3: "Inconclusive", 4: "Unspecified", 5: "Probe"}
def outcome2str(outcome: int):
    return MAPPING.get(outcome, "Discrepant") # if not one of above is Discrepant

# %%
def show_assay_report(SID: int):
    print("SID:", SID)
    assay_outcomes = get_assay_outcomes(SID)
    assay_outcomes_df = pd.DataFrame(assay_outcomes)
    assay_outcomes_df.rename(columns={"aid": "AID", "outcome": "OutcomeCode"}, inplace=True)
    assay_outcomes_df["Outcome"] = assay_outcomes_df["OutcomeCode"].apply(lambda o: outcome2str(o))
    print(f"Total number of bioassays with SID={SID} in {DATABASE} DB: {len(assay_outcomes_df["AID"])}")
    print("\nActivity Outcomes:")
    print(f"{assay_outcomes_df["Outcome"].value_counts()}\n")
    # sample first 20 rows and provide links to assay IDs
    sample_i = min(20, len(assay_outcomes_df))
    assay_outcomes_df_sample = assay_outcomes_df.iloc[0:sample_i]
    if sample_i < len(assay_outcomes_df):
        print("Sample of 20 assay outcomes:")
    else:
        print("All assay outcomes:")
    create_clickable_df(assay_outcomes_df_sample, ["AID"], [ASSAY_BASE_URL])

# %% [markdown]
# #### SID: [858057](https://pubchem.ncbi.nlm.nih.gov/substance/858057)
# Associated compound CID=[659413](https://pubchem.ncbi.nlm.nih.gov/compound/659413).

# %%
show_assay_report(SID=858057)
# Out:
# SID: 858057
# Total number of bioassays with SID=858057 in badapple2 DB: 689
#
# Activity Outcomes:
# Outcome
# Inactive        526
# Active          105
# Inconclusive     57
# Unspecified       1
# Name: count, dtype: int64
#
# Sample of 20 assay outcomes:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>AID</th>
#       <th>OutcomeCode</th>
#       <th>Outcome</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/361" target="_blank">361</a></td>
#       <td>2</td>
#       <td>Active</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/368" target="_blank">368</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/373" target="_blank">373</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/374" target="_blank">374</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/411" target="_blank">411</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/422" target="_blank">422</a></td>
#       <td>2</td>
#       <td>Active</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/425" target="_blank">425</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/429" target="_blank">429</a></td>
#       <td>2</td>
#       <td>Active</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/430" target="_blank">430</a></td>
#       <td>2</td>
#       <td>Active</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/431" target="_blank">431</a></td>
#       <td>2</td>
#       <td>Active</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/432" target="_blank">432</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/436" target="_blank">436</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/449" target="_blank">449</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/453" target="_blank">453</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/460" target="_blank">460</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/518" target="_blank">518</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/521" target="_blank">521</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/522" target="_blank">522</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/524" target="_blank">524</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/525" target="_blank">525</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### SID: [49734932](https://pubchem.ncbi.nlm.nih.gov/substance/49734932)
# Associated compound CID=[5052536](https://pubchem.ncbi.nlm.nih.gov/compound/5052536).

# %%
show_assay_report(SID=49734932)
# Out:
# SID: 49734932
# Total number of bioassays with SID=49734932 in badapple2 DB: 509
#
# Activity Outcomes:
# Outcome
# Inactive        412
# Active           53
# Inconclusive     43
# Unspecified       1
# Name: count, dtype: int64
#
# Sample of 20 assay outcomes:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>AID</th>
#       <th>OutcomeCode</th>
#       <th>Outcome</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/1490" target="_blank">1490</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/1511" target="_blank">1511</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/1527" target="_blank">1527</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/1529" target="_blank">1529</a></td>
#       <td>2</td>
#       <td>Active</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/1530" target="_blank">1530</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/1531" target="_blank">1531</a></td>
#       <td>2</td>
#       <td>Active</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/1554" target="_blank">1554</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/1556" target="_blank">1556</a></td>
#       <td>2</td>
#       <td>Active</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/1565" target="_blank">1565</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/1566" target="_blank">1566</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/1578" target="_blank">1578</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/1621" target="_blank">1621</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/1631" target="_blank">1631</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/1634" target="_blank">1634</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/1654" target="_blank">1654</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/1656" target="_blank">1656</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/1662" target="_blank">1662</a></td>
#       <td>2</td>
#       <td>Active</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/1663" target="_blank">1663</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/1672" target="_blank">1672</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/1700" target="_blank">1700</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### SID [49736157](https://pubchem.ncbi.nlm.nih.gov/substance/49736157) and [144090604](https://pubchem.ncbi.nlm.nih.gov/substance/144090604)
# Both of these substances are standardized to CID=[20868233](https://pubchem.ncbi.nlm.nih.gov/compound/20868233).

# %%
show_assay_report(SID=49736157)
# Out:
# SID: 49736157
# Total number of bioassays with SID=49736157 in badapple2 DB: 440
#
# Activity Outcomes:
# Outcome
# Inactive        373
# Inconclusive     35
# Active           31
# Unspecified       1
# Name: count, dtype: int64
#
# Sample of 20 assay outcomes:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>AID</th>
#       <th>OutcomeCode</th>
#       <th>Outcome</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/1490" target="_blank">1490</a></td>
#       <td>2</td>
#       <td>Active</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/1511" target="_blank">1511</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/1527" target="_blank">1527</a></td>
#       <td>2</td>
#       <td>Active</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/1529" target="_blank">1529</a></td>
#       <td>2</td>
#       <td>Active</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/1530" target="_blank">1530</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/1531" target="_blank">1531</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/1554" target="_blank">1554</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/1556" target="_blank">1556</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/1565" target="_blank">1565</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/1566" target="_blank">1566</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/1578" target="_blank">1578</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/1621" target="_blank">1621</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/1631" target="_blank">1631</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/1634" target="_blank">1634</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/1654" target="_blank">1654</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/1656" target="_blank">1656</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/1662" target="_blank">1662</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/1663" target="_blank">1663</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/1672" target="_blank">1672</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/1700" target="_blank">1700</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#   </tbody>
# </table>

# %%
show_assay_report(SID=144090604)
# Out:
# SID: 144090604
# Total number of bioassays with SID=144090604 in badapple2 DB: 1
#
# Activity Outcomes:
# Outcome
# Inactive    1
# Name: count, dtype: int64
#
# All assay outcomes:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>AID</th>
#       <th>OutcomeCode</th>
#       <th>Outcome</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><a href="https://pubchem.ncbi.nlm.nih.gov/bioassay/743445" target="_blank">743445</a></td>
#       <td>1</td>
#       <td>Inactive</td>
#     </tr>
#   </tbody>
# </table>
